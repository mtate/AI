# %% [markdown]
# # 🌍🌎🌏 USGS Earthquakes data by Region (1900-2026)

# %% [markdown]
# ## Data Source
#
# look at "query" in https://earthquake.usgs.gov/fdsnws/event/1/
# ## Data Dictionary
#
#     https://earthquake.usgs.gov/data/comcat/index.php
#     https://earthquake.usgs.gov/earthquakes/feed/v1.0/geojson.php
#     https://earthquake.usgs.gov/earthquakes/feed/v1.0/geojson_detail.php
#
# ## Continent, Region, and Country Fields
#
# Using the coordinates given, I used reverse_geocoder and country_converter libraries to populate these new fields
# Navigate to geojson event detail(s)
#
#     https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=XXXXX&format=geojson
#
# where XXXXX is Id of the event

# %% [markdown]
# ## Missing Data
#
# *According to USGS*
#
#     We may not rapidly locate earthquakes smaller than 5.0 outside the U.S. unless they have caused significant damage or are widely felt. Earthquakes this small rarely cause significant damage. At times, some other agency may report an earthquake with a larger magnitude than what we compute from our data, especially for non-U.S. events near magnitude 5.0. If our magnitude for the event is less than magnitude 5.0, we may not issue a rapid report for it.

# %%
#Import libraries
import warnings
import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.tree import DecisionTreeClassifier, plot_tree, export_text
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score, roc_auc_score, confusion_matrix

warnings.filterwarnings("ignore")
RANDOM_STATE = 42
np.random.seed(RANDOM_STATE)
random.seed(RANDOM_STATE)
sns.set_theme(style="whitegrid")

print("Libraries imported successfully.")
# Out:
# Libraries imported successfully.

# %% [markdown]
# ## Load and Inspect the Dataset
#
# The dataset is loaded from the CSV file and its structure is inspected before modeling.

# %%
DATA_PATH = "Antarctica_USGS_Earthquakes.csv"
df = pd.read_csv(DATA_PATH)

print("Dataset shape:", df.shape)
print("\nFirst 10 rows:")
print(df.head(10).to_string(index=False))
print("\nLast 10 rows:")
print(df.tail(10).to_string(index=False))
print("\nColumn data types:")
print(df.dtypes)
print("\nDataset loaded successfully.")
# Out:
# Dataset shape: (537, 10)
#
# First 10 rows:
#         id  mag                  place                    time                 updated  tz  felt  cdi   mmi alert
# us6000tkvi  5.3 Balleny Islands region 2026-08-15 08:40:13.397 2026-08-15 08:58:24.040 NaN   NaN  NaN   NaN   NaN
# us7000sz2b  5.5 Balleny Islands region 2026-07-09 03:07:10.909 2026-07-10 03:36:31.569 NaN   NaN  NaN 0.000 green
# us6000t9zw  5.3 Balleny Islands region 2026-07-04 04:22:15.219 2026-07-04 04:50:26.040 NaN   NaN  NaN   NaN   NaN
# us6000sgkw  5.4 Balleny Islands region 2026-03-16 21:01:42.178 2026-03-18 21:58:58.040 NaN   NaN  NaN 0.000 green
# us6000samt  5.6 Balleny Islands region 2026-02-22 01:01:49.995 2026-02-26 01:40:57.436 NaN   NaN  NaN 0.000 green
# us6000rw6a  5.3 Balleny Islands region 2025-12-20 18:25:04.033 2025-12-20 18:42:38.040 NaN   NaN  NaN   NaN   NaN
# us6000rw5u  5.6 Balleny Islands region 2025-12-20 14:57:09.861 2025-12-21 15:18:46.735 NaN   NaN  NaN 0.000 green
# ...
